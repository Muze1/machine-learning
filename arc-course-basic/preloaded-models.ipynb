# %%
from tensorflow.keras.applications import VGG16
# Out:
# 2025-05-08 16:36:45.410915: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = VGG16(weights="imagenet")
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 34s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

# %%
def show_image(image_path):
    image = mping.imread(image_path)
    print(image)
    plt.imshow(image)

# %%
path = "pretrained_models_and_transfer_learning/data/doggy_door_data/happy_dog.jpg"
show_image(path)
# Out:
# [[[121 159  37]
#   [125 163  41]
#   [127 165  43]
#   ...
#   [ 67  71  48]
#   [ 68  72  49]
#   [ 66  70  47]]
#
#  [[125 164  39]
#   [127 165  43]
#   [128 166  44]
#   ...
#   [ 64  68  43]
#   [ 66  70  45]
#   [ 66  70  45]]
#
#  [[126 165  38]
#   [124 163  38]
#   [125 164  39]
#   ...
#   [ 67  73  47]
#   [ 70  76  50]
#   [ 72  78  52]]
#
#  ...
#
#  [[209 208 151]
#   [207 206 141]
#   [200 198 123]
#   ...
#   [ 71  97   0]
#   [ 98 129  10]
#   [129 163  27]]
#
#  [[209 211 146]
#   [206 207 137]
#   [204 203 123]
#   ...
#   [105 139   3]
#   [126 163  21]
#   [180 218  70]]
#
#  [[202 208 138]
#   [199 203 127]
#   [200 202 118]
#   ...
#   [129 168  13]
#   [120 159   8]
#   [176 215  72]]]

# %%
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.applications.vgg16 import preprocess_input

def load_and_process_image(image_path):
    # Print image's original shape, for reference
    print('Original image shape: ', mpimg.imread(image_path).shape)
    
    # Load in the image with a target size of 224, 224
    image = image_utils.load_img(image_path, target_size=(224, 224))
    # Convert the image from a PIL format to a numpy array
    image = image_utils.img_to_array(image)
    # Add a dimension for number of images, in our case 1
    image = image.reshape(1,224,224,3)
    # Preprocess image to align with original ImageNet dataset
    image = preprocess_input(image)
    # Print image's shape after processing
    print('Processed image shape: ', image.shape)
    return image

# %%
processed_image = load_and_process_image("pretrained_models_and_transfer_learning/data/doggy_door_data/brown_bear.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 processed_image = load_and_process_image("pretrained_models_and_transfer_learning/data/doggy_door_data/brown_bear.jpg")
#
# Cell In[23], line 6, in load_and_process_image(image_path)
#       4 def load_and_process_image(image_path):
#       5     # Print image's original shape, for reference
# ----> 6     print('Original image shape: ', mpimg.imread(image_path).shape)
#       8     # Load in the image with a target size of 224, 224
#       9     image = image_utils.load_img(image_path, target_size=(224, 224))
#
# NameError: name 'mpimg' is not defined

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions

model.predict(processed_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 from tensorflow.keras.applications.vgg16 import decode_predictions
# ----> 3 model.predict(processed_image)
#
# NameError: name 'processed_image' is not defined
